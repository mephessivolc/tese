# %%
from objective_function import PyomoObjectiveBuilder as pob, ObjectiveFunctionExtractor as ofe

# %%
n=5
graphs = GraphBuilder(n)
print(graphs.matrix)

graphs.draw(figname=f"graph_{n}v.png")
# Out:
# [[0 5 9 2 9]
#  [5 0 5 7 2]
#  [9 5 0 9 6]
#  [2 7 9 0 7]
#  [9 2 6 7 0]]

# %%
m = pob(graphs.graph)
m.function.pprint()

# %%
ext = ofe(m.function.OBJ)

print(ext.constant)
print(ext.linear_terms)
print(ext.quadratic_terms)
