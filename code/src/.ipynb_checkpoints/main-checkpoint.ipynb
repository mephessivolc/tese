# %%
from objective_function import PyomoObjectiveBuilder as pob
from graphs import GraphBuilder

# %%
n=3
graphs = GraphBuilder(n)

graphs.draw()

# %%
m = pob(graphs.graph)
m.build()
m.m.pprint()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 m = pob(graphs.G)
#       2 m.build()
#       3 m.m.pprint()
#
# AttributeError: 'GraphBuilder' object has no attribute 'G'

# %%
print(m.OBJ.expr)

# %%
dict_objf = objfunc.function_objective_to_indexed_dict(m.OBJ)

# %%
print(dict_objf)
